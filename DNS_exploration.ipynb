# %% [markdown]
# <a href="https://colab.research.google.com/github/ft10101/Python-For-CyberSecurity/blob/main/DNS_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install dnspython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 KB 9.7 MB/s eta 0:00:00
# ...

# %%
import dns
import dns.resolver
import socket

# %%
def ReverseDNS(ip):
  try:
    result = socket.gethostbyaddr(ip)
  except:
    return []
  return [result[0]]+result[1]

# %%
def DNSRequest(domain):
  try:
    result = dns.resolver.resolve(domain,'A')
    if result:
      print(domain)
      for answer in result:
        print(answer)
        print("Domain Names: %s" % ReverseDNS(answer.to_text()))
  except(dns.resolver.NXDOMAIN , dns.exception.Timeout):
    return

# %%
def SubdomainSearch(domain,dictionary,nums):
  for word in dictionary:
    subdomain = word+ "." +domain
    DNSRequest(subdomain)
    if nums:
      for i in range(0,10):
        s = word + str(i) + "." +domain
        DNSRequest(s)

# %%
 domain = "google.com"
 d = "/content/subdomains.txt"
 dictionary = []
 with open(d,"r") as f:
   dictionary = f.read().splitlines()
SubdomainSearch(domain,dictionary,True)
# Out:
# www.google.com
# 74.125.142.105
# Domain Names: ['ie-in-f105.1e100.net']
# 74.125.142.103
# Domain Names: ['ie-in-f103.1e100.net']
# 74.125.142.104
# Domain Names: ['ie-in-f104.1e100.net']
# 74.125.142.106
# Domain Names: ['pv-in-f106.1e100.net']
# 74.125.142.99
# Domain Names: ['pv-in-f99.1e100.net']
# 74.125.142.147
# Domain Names: ['pv-in-f147.1e100.net']
# www4.google.com
# 74.125.195.118
# Domain Names: ['pw-in-f118.1e100.net']
# www5.google.com
# 173.194.202.105
# Domain Names: ['pf-in-f105.1e100.net']
# 173.194.202.99
# Domain Names: ['pf-in-f99.1e100.net']
# 173.194.202.147
# Domain Names: ['pf-in-f147.1e100.net']
# 173.194.202.106
# Domain Names: ['pf-in-f106.1e100.net']
# 173.194.202.104
# Domain Names: ['pf-in-f104.1e100.net']
# 173.194.202.103
# Domain Names: ['pf-in-f103.1e100.net']
# www6.google.com
# 74.125.195.99
# Domain Names: ['wj-in-f99.1e100.net']
# 74.125.195.103
# Domain Names: ['pw-in-f103.1e100.net']
# 74.125.195.105
# Domain Names: ['wj-in-f105.1e100.net']
# ...
